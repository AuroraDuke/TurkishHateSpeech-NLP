# %%
import pandas as pd
import re
import emoji
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ilker\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def tokinize_and_filter(sentence):
    if not isinstance(sentence, str):  # Return the original value if the cell is not a string
        return sentence

    # Print input text
    #print(f"Original text: {sentence}")
    # Remove URLs
    sentence = re.sub(r"http\S+|www\S+|https\S+", "", sentence)

    # Remove emojis
    sentence = emoji.replace_emoji(sentence, " ")
  
    # Convert text to lowercase and remove punctuation
    sentence = re.sub(r"""[\.,!?;:\"'\(\)\[\]{}<>@#$%^&*\-_+=|\\/~`]+""", " ", sentence.lower())
    sentence = re.sub(r"  ", " ", sentence)

    #convert from sentence to token
    tokens = word_tokenize(sentence, language='turkish')
    
    # Load Turkish stopwords
    turkce_stopwords = set(stopwords.words('turkish'))
    # Split text and filter out stopwords
    filtered_tokens = [word for word in tokens if word not in turkce_stopwords and word.isalnum()]

    # Join the filtered tokens back into a string
    result = " ".join(filtered_tokens)

    # Print output text
   # print(f"Filtered text: {result}")

    return result

# %%
hate = pd.read_csv("data_Llama_mapping_hate.csv")
aı = pd.read_csv("data_Llama_mapping.csv")
llama_dataset = pd.concat([hate,aı],axis=0)

# %%
llama_dataset
# Out:
#                                                   tweet     etiket
# 0     Avrupa kafasıyla imzalanmış bir sözleşmeye gör...     nefret
# 1     Avrupa'nın kafasızca imzaladığı bir sözleşmeyl...     nefret
# 2     Kadını koruma için neden dine sığınmak lazım? ...     nefret
# 3     ülkede oturup türk vatandaşı olup türkler 8009...     nefret
# 4     Müslümanlarla problemi olan Türklerin başka ül...     nefret
# ...                                                 ...        ...
# 3202  Büyükelçiler bile Suriye'de yaşama istemedikle...  saldırgan
# 3203  Orospu çocukları hepsi aynı anda yazıyonusun t...  saldırgan
# 3204  Bu pis çocuklardan daha nice surprise alırsam ...  saldırgan
# 3205  Orospu çocuklarından başka hiçbir şey anlamıyo...  saldırgan
# 3206  Sur ve kavgayı seven bu pis kokulu çocuklar ba...  saldırgan
#
# [6414 rows x 2 columns]

# %%
if 'tweet' in llama_dataset.columns:
    llama_dataset['tweet'] = llama_dataset['tweet'].apply(tokinize_and_filter)

# %%
llama_dataset
# Out:
#                                                   tweet     etiket
# 0     avrupa kafasıyla imzalanmış bir sözleşmeye gör...     nefret
# 1     avrupa nın kafasızca imzaladığı bir sözleşmeyl...     nefret
# 2     kadını koruma dine sığınmak lazım insan yapalı...     nefret
# 3     ülkede oturup türk vatandaşı olup türkler 8009...     nefret
# 4     müslümanlarla problemi olan türklerin başka ül...     nefret
# ...                                                 ...        ...
# 3202  büyükelçiler bile suriye yaşama istemedikleri ...  saldırgan
# 3203  orospu çocukları aynı anda yazıyonusun tam cid...  saldırgan
# 3204  pis çocuklardan nice surprise alırsam hepsini ...  saldırgan
# 3205  orospu çocuklarından başka hiçbir anlamıyorum ...  saldırgan
# 3206         sur kavgayı seven pis kokulu çocuklar bana  saldırgan
#
# [6414 rows x 2 columns]

# %%
llama_dataset.to_csv("Llama_tokenized.csv", index=False,encoding='utf-8-sig')
